# %%
import psycopg2
import pandas as pd
import seaborn as sns
import matplotlib as plt
import scipy
# Out:
# /Users/candyg/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
connection = psycopg2.connect(
    host = 'diasterdb2.cbyvxmyzmzyh.us-east-2.rds.amazonaws.com',
    port = 5432,
    user = 'postgres',
    password = 'group7_db',
    database='diasterdb'
    )
cursor=connection.cursor()

# %%
sql = """
SELECT "table_name","column_name", "data_type", "table_schema"
FROM INFORMATION_SCHEMA.COLUMNS
WHERE "table_schema" = 'public'
ORDER BY table_name  
"""
pd.read_sql(sql, con=connection)
# Out:
#      table_name                     column_name          data_type  \
# 0          FPIS                            NAME  character varying
# 1          FPIS                         FIPS_ID            integer
# 2   TEMPERATURE                            DATE               date
# 3   TEMPERATURE                         Country  character varying
# 4   TEMPERATURE  AverageTemperatureUncertaintyF            numeric
# 5   TEMPERATURE                           STATE  character varying
# 6   TEMPERATURE                  TEMPERATURE_ID            integer
# 7   TEMPERATURE                      Fahrenheit            numeric
# 8   TEMPERATURE             AverageTemperatureF            numeric
# 9    USDisaster             pa_program_declared            integer
# 10   USDisaster      declaration_request_number            integer
# 11   USDisaster                fema_declaration  character varying
# 12   USDisaster                 designated_area  character varying
# 13   USDisaster                declaration_type  character varying
# 14   USDisaster             ih_program_declared            integer
# 15   USDisaster                   incident_type  character varying
# 16   USDisaster                           state  character varying
# 17   USDisaster                            fips            integer
# 18   USDisaster                     fy_declared            integer
# 19   USDisaster                declaration_date               date
# 20   USDisaster                      place_code  character varying
# 21   USDisaster                    last_refresh               date
# 22   USDisaster                              id  character varying
# 23   USDisaster             ia_program_declared            integer
# 24   USDisaster             hm_program_declared            integer
# 25   USDisaster                            hash  character varying
# 26   USDisaster                 disaster_number            integer
# 27   USDisaster               declaration_title  character varying
# 28   USDisaster             incident_begin_date               date
# 29     USStates               PostalAbreviation  character varying
# 30     USStates                StateDescription  character varying
#
#    table_schema
# 0        public
# 1        public
# 2        public
# 3        public
# 4        public
# 5        public
# 6        public
# 7        public
# 8        public
# 9        public
# 10       public
# 11       public
# 12       public
# 13       public
# 14       public
# 15       public
# 16       public
# 17       public
# 18       public
# 19       public
# 20       public
# 21       public
# 22       public
# 23       public
# 24       public
# 25       public
# 26       public
# 27       public
# 28       public
# 29       public
# 30       public

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
sql_USDisaster = """ SELECT * FROM public."USDisaster" """
df_US_disasters = pd.read_sql(sql_USDisaster, con=connection)
df_US_disasters.tail(3)
# Out:
#       fema_declaration  disaster_number state declaration_type  \
# 61803       DR-4610-CA             4610    CA               DR
# 61804       DR-4610-CA             4610    CA               DR
# 61805       FM-5416-CA             5416    CA               FM
#
#       declaration_date  fy_declared incident_type declaration_title  \
# 61803       2021-08-24         2021          Fire         Wildfires
# 61804       2021-08-24         2021          Fire         Wildfires
# 61805       2021-08-25         2021          Fire       French Fire
#
#        ih_program_declared  ia_program_declared  pa_program_declared  \
# 61803                    1                    0                    1
# 61804                    1                    0                    1
# 61805                    0                    0                    1
#
#        hm_program_declared incident_begin_date  fips place_code  \
# 61803                    1          2021-07-14  6035      99035
# 61804                    1          2021-07-14  6057      99057
# 61805                    1          2021-08-24  6029      99029
#
#        designated_area  declaration_request_number  \
# 61803  Lassen (County)                       21087
# 61804  Nevada (County)                       21087
# 61805    Kern (County)                       21088
#
#                                            hash last_refresh  \
# 61803  74f77c93f158659bf1dd9f871227a9993244478d   2021-08-25
# 61804  dde89f65556f220034ac16cfa66abf7d135962da   2021-08-25
# 61805  b2120fdada11e2ceefe3714927afe2443c719812   2021-08-25
#
#                              id
# 61803  6125a937434e34d5ee5cd8a3
# 61804  6125a937434e34d5ee5cd8c1
# 61805  61266e5e434e34d5eee6f25e

# %%
df_US_disasters['declaration_date'].astype(str)
df_US_disasters['year'] = pd.DatetimeIndex(df_US_disasters['declaration_date']).year
df_US_disasters['month'] = pd.DatetimeIndex(df_US_disasters['declaration_date']).month
df_US_disasters['month_year'] = pd.to_datetime(df_US_disasters['declaration_date']).dt.to_period('M')
df_US_disasters
# Out:
#       fema_declaration  disaster_number state declaration_type  \
# 0              DR-1-GA                1    GA               DR
# 1              DR-2-TX                2    TX               DR
# 2              DR-3-LA                3    LA               DR
# 3              DR-4-MI                4    MI               DR
# 4              DR-5-MT                5    MT               DR
# ...                ...              ...   ...              ...
# 61801       DR-4610-CA             4610    CA               DR
# 61802       DR-4610-CA             4610    CA               DR
# 61803       DR-4610-CA             4610    CA               DR
# 61804       DR-4610-CA             4610    CA               DR
# 61805       FM-5416-CA             5416    CA               FM
#
#       declaration_date  fy_declared incident_type         declaration_title  \
# 0           1953-05-02         1953       Tornado                   Tornado
# 1           1953-05-15         1953       Tornado  Tornado & Heavy Rainfall
# 2           1953-05-29         1953         Flood                     Flood
# 3           1953-06-02         1953       Tornado                   Tornado
# 4           1953-06-06         1953         Flood                    Floods
# ...                ...          ...           ...                       ...
# 61801       2021-08-24         2021          Fire                 Wildfires
# 61802       2021-08-24         2021          Fire                 Wildfires
# 61803       2021-08-24         2021          Fire                 Wildfires
# 61804       2021-08-24         2021          Fire                 Wildfires
# 61805       2021-08-25         2021          Fire               French Fire
#
#        ih_program_declared  ia_program_declared  ...   fips  place_code  \
# 0                        0                    1  ...  13000           0
# 1                        0                    1  ...  48000           0
# 2                        0                    1  ...  22000           0
# 3                        0                    1  ...  26000           0
# 4                        0                    1  ...  30000           0
# ...                    ...                  ...  ...    ...         ...
# 61801                    1                    0  ...   6063       99063
# 61802                    1                    0  ...   6061       99061
# 61803                    1                    0  ...   6035       99035
# 61804                    1                    0  ...   6057       99057
# 61805                    0                    0  ...   6029       99029
#
#        designated_area  declaration_request_number  \
# 0            Statewide                       53013
# 1            Statewide                       53003
# 2            Statewide                       53005
# 3            Statewide                       53004
# 4            Statewide                       53006
# ...                ...                         ...
# 61801  Plumas (County)                       21087
# 61802  Placer (County)                       21087
# 61803  Lassen (County)                       21087
# 61804  Nevada (County)                       21087
# 61805    Kern (County)                       21088
#
#                                            hash last_refresh  \
# 0      bb121323c9c29d3bef0c9a3f134bfd8b5ecff148   2021-07-13
# 1      c879557e78d059e6847e7688388c339d10f51979   2021-07-13
# 2      4fb19699fdbba1387ffa2263fcc4a4e37a1de6d6   2021-07-13
# 3      87a0c1dd5da249767f545e0c0a43f917e4e9ca83   2021-07-13
# 4      954449c15634fb45c8bea3ac975782793ccde050   2021-07-13
# ...                                         ...          ...
# 61801  d615785ddbaca2e0dbb66805d84246680c86f560   2021-08-25
# 61802  6e1ab1c91a9838148684d35413b598c5ea66df71   2021-08-25
# 61803  74f77c93f158659bf1dd9f871227a9993244478d   2021-08-25
# 61804  dde89f65556f220034ac16cfa66abf7d135962da   2021-08-25
# 61805  b2120fdada11e2ceefe3714927afe2443c719812   2021-08-25
#
#                              id  year month month_year
# 0      60c3b7a9a0ee349d71025780  1953     5    1953-05
# 1      60c3b7a9a0ee349d71025783  1953     5    1953-05
# 2      60c3b7a9a0ee349d71025777  1953     5    1953-05
# 3      60c3b7a9a0ee349d7102577a  1953     6    1953-06
# 4      60c3b7a9a0ee349d71025774  1953     6    1953-06
# ...                         ...   ...   ...        ...
# 61801  6125a937434e34d5ee5cd8af  2021     8    2021-08
# 61802  6125a937434e34d5ee5cd8b6  2021     8    2021-08
# 61803  6125a937434e34d5ee5cd8a3  2021     8    2021-08
# 61804  6125a937434e34d5ee5cd8c1  2021     8    2021-08
# 61805  61266e5e434e34d5eee6f25e  2021     8    2021-08
#
# [61806 rows x 23 columns]

# %%
df_US_disasters_clean = df_US_disasters.drop(columns=['ia_program_declared', 
                          'last_refresh', 'hash','id', 'ih_program_declared', 'pa_program_declared', 
                          'hm_program_declared','month','place_code'])

# %%
num_disasters_series = df_US_disasters_clean.groupby("year")['incident_type'].count()
df_num_disasters_us = pd.Series(num_disasters_series).to_frame().reset_index()
df_num_disasters_us=df_num_disasters_us.rename(columns = {"incident_type":"incident frequency"})

# %%
sql_temp = """ SELECT * FROM public."TEMPERATURE" """
df_US_temperatures = pd.read_sql(sql_temp, con=connection)

# %%
df_US_temperatures['DATE'].astype(str)
df_US_temperatures['year'] = pd.DatetimeIndex(df_US_temperatures['DATE']).year
df_US_temperatures['month'] = pd.DatetimeIndex(df_US_temperatures['DATE']).month
df_US_temperatures['month_year'] = pd.to_datetime(df_US_temperatures['DATE']).dt.to_period('M')
df_US_temperatures.head()
# Out:
#    TEMPERATURE_ID        DATE    STATE        Country  Fahrenheit  \
# 0               1  1953-01-01  Alabama  United States     119.381
# 1               2  1953-02-01  Alabama  United States     118.634
# 2               3  1953-03-01  Alabama  United States     164.363
# 3               4  1953-04-01  Alabama  United States     175.298
# 4               5  1953-05-01  Alabama  United States     241.619
#
#    AverageTemperatureF  AverageTemperatureUncertaintyF  year  month month_year
# 0              49.4762                         32.2808  1953      1    1953-01
# 1              49.3268                         32.2286  1953      2    1953-02
# 2              58.4726                         32.1728  1953      3    1953-03
# 3              60.6596                         32.2916  1953      4    1953-04
# 4              73.9238                         32.3420  1953      5    1953-05

# %%
df_US_temperatures['STATE'] = df_US_temperatures['STATE'].map(us_state_abbrev).fillna(df_US_temperatures['STATE'])
df_US_temperatures
# Out:
#        TEMPERATURE_ID        DATE STATE        Country  Fahrenheit  \
# 0                   1  1953-01-01    AL  United States     119.381
# 1                   2  1953-02-01    AL  United States     118.634
# 2                   3  1953-03-01    AL  United States     164.363
# 3                   4  1953-04-01    AL  United States     175.298
# 4                   5  1953-05-01    AL  United States     241.619
# ...               ...         ...   ...            ...         ...
# 37172           37173  2013-05-01    WY  United States     127.463
# 37173           37174  2013-06-01    WY  United States     178.403
# 37174           37175  2013-07-01    WY  United States     213.998
# 37175           37176  2013-08-01    WY  United States     208.589
# 37176           37177  2013-09-01    WY  United States     174.299
#
#        AverageTemperatureF  AverageTemperatureUncertaintyF  year  month  \
# 0                  49.4762                         32.2808  1953      1
# 1                  49.3268                         32.2286  1953      2
# 2                  58.4726                         32.1728  1953      3
# 3                  60.6596                         32.2916  1953      4
# 4                  73.9238                         32.3420  1953      5
# ...                    ...                             ...   ...    ...
# 37172              51.0926                         32.3744  2013      5
# 37173              61.2806                         32.4968  2013      6
# 37174              68.3996                         32.2394  2013      7
# 37175              67.3178                         32.3906  2013      8
# 37176              60.4598                         33.9818  2013      9
#
#       month_year
# 0        1953-01
# 1        1953-02
# 2        1953-03
# 3        1953-04
# 4        1953-05
# ...          ...
# 37172    2013-05
# 37173    2013-06
# 37174    2013-07
# 37175    2013-08
# 37176    2013-09
#
# [37177 rows x 10 columns]

# %%
series_temp = df_US_temperatures.groupby("year")['AverageTemperatureF'].mean()
df_annual_US_temp = pd.Series(series_temp).to_frame().reset_index()
df_annual_US_temp
# Out:
#     year  AverageTemperatureF
# 0   1953            53.365676
# 1   1954            52.888285
# 2   1955            51.751159
# 3   1956            51.934794
# 4   1957            52.198468
# ..   ...                  ...
# 56  2009            52.081388
# 57  2010            53.119179
# 58  2011            53.259968
# 59  2012            54.971315
# 60  2013            55.539726
#
# [61 rows x 2 columns]

# %%
# plot annual US average temperature from 1953-2013
# df_annual_US_temp.plot.line()
#ax = sns.lineplot(data=df_annual_US_temp, x="year", y="AverageTemperatureF")
ax = sns.lmplot(x="year", y="AverageTemperatureF", data=df_annual_US_temp,aspect=1.7, height=5,markers=['o'], scatter_kws={'s':20})
ax.set(title='Annual US Temperature from 1953-2013', ylabel='Average Temperature (F)', xlabel="Year")
ax.set(xlim=(1950, 2015))
ax.set(ylim=(50, 58))

# %%
df_combined = pd.merge(left = df_num_disasters_us, right = df_annual_US_temp, on = "year")

# %%
df_combined.tail(10)
# Out:
#     year  incident frequency  AverageTemperatureF
# 51  2004                1853            52.804868
# 52  2005                4736            53.309032
# 53  2006                 975            54.029271
# 54  2007                1639            53.388056
# 55  2008                2300            52.148576
# 56  2009                1264            52.081388
# 57  2010                1631            53.119179
# 58  2011                2690            53.259968
# 59  2012                1292            54.971315
# 60  2013                 769            55.539726

# %%
ax = sns.lmplot(x="year", y="incident frequency", data=df_combined, aspect=1.7, height=5,markers=['o'], scatter_kws={'s':20})
ax.set(title='Effect of temperature on disaster frequency', ylabel='Average Temperature (F)', xlabel="Number of disasters per year")
#ax.set(xlim=(0, 3000))
#ax.set(ylim=(50, 58))

# %%
df_combined_no_bio = df_combined.drop(index=52)

# %%
ax = sns.lmplot(x="year", y="incident frequency", data= df_combined_no_bio, aspect=1.7, height=5,markers=['o'], scatter_kws={'s':20})
ax.set(title='Natural disaster frequency over time', ylabel='Number of natural disasters', xlabel="Year")
ax.set(xlim=(1950, 2015))
ax.set(ylim=(0, 3000))

# %%
ax = sns.lmplot(x="incident frequency", y="AverageTemperatureF", data=df_combined_no_bio, fit_reg = True, aspect=1.7, height=5,markers=['o'], scatter_kws={'s':20})
ax.set(title='Effect of temperature on disaster frequency', ylabel='Average Temperature (F)', xlabel="Number of disasters per year")
# ax.set(xlim=(0, 3000))
# ax.set(ylim=(50, 58))

# slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(df_combined['incident frequency'],df_combined['AverageTemperatureF'])
# label_line_1 = r'$y={0:.1f}x+{1:.1f}'.format(slope,intercept)
# L_labels.set_text(label_line_1)

# slope, intercept, r_value, pv, se = scipy.stats.linregress(df_combined['incident frequency'],df_combined['AverageTemperatureF'])

# sns.regplot(x="incident frequency", y="AverageTemperatureF", data=df_combined, 
#       ci=None, label="y={0:.1f}x+{1:.1f}".format(slope, intercept, r_value, p_value)).legend(loc="best")

r, p = scipy.stats.pearsonr(df_combined_no_bio['incident frequency'], df_combined_no_bio['AverageTemperatureF'])
print (f'The pearson r correlation coefficient is {r} and the p value is {p}.')
# Out:
# The pearson r correlation coefficient is 0.4127770588484668 and the p value is 0.0010470388584527819.
